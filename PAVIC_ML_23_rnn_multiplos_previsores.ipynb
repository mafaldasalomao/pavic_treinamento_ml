# %% [markdown]
# <a href="https://colab.research.google.com/github/mafaldasalomao/pavic_treinamento_ml/blob/main/PAVIC_ML_23_rnn_multiplos_previsores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Previsão do preço de ações com redes neurais recorrentes - múltiplos previsores

# %% [markdown]
# ## Etapa 1: Importação das bibliotecas

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import torch
from torch import nn, optim
from sklearn.metrics import mean_absolute_error
torch.__version__
# Out:
# '2.0.1+cu118'

# %%
torch.manual_seed(123)

# %% [markdown]
# ## Etapa 2: Base de dados

# %%
base = pd.read_csv('petr4_treinamento.csv')
base = base.dropna()
base_treinamento = base.iloc[:, 1:7].values #sete nao entra eh uperbound

# %%
base_treinamento
# Out:
# array([[1.9990000e+01, 2.0209999e+01, 1.9690001e+01, 1.9690001e+01,
#         1.8086271e+01, 3.0182600e+07],
#        [1.9809999e+01, 2.0400000e+01, 1.9700001e+01, 2.0400000e+01,
#         1.8738441e+01, 3.0552600e+07],
#        [2.0330000e+01, 2.0620001e+01, 2.0170000e+01, 2.0430000e+01,
#         1.8766001e+01, 3.6141000e+07],
#        ...,
#        [1.5990000e+01, 1.6139999e+01, 1.5980000e+01, 1.6049999e+01,
#         1.6017963e+01, 2.3552200e+07],
#        [1.6100000e+01, 1.6129999e+01, 1.6000000e+01, 1.6100000e+01,
#         1.6067865e+01, 1.9011500e+07],
#        [1.6100000e+01, 1.6100000e+01, 1.6100000e+01, 1.6100000e+01,
#         1.6067865e+01, 0.0000000e+00]])

# %%
base.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2013-01-02  19.990000  20.209999  19.690001  19.690001  18.086271
# 1  2013-01-03  19.809999  20.400000  19.700001  20.400000  18.738441
# 2  2013-01-04  20.330000  20.620001  20.170000  20.430000  18.766001
# 3  2013-01-07  20.480000  20.670000  19.950001  20.080000  18.444506
# 4  2013-01-08  20.110001  20.230000  19.459999  19.500000  17.911745
#
#        Volume
# 0  30182600.0
# 1  30552600.0
# 2  36141000.0
# 3  28069600.0
# 4  29091300.0

# %%
normalizador = MinMaxScaler(feature_range = (0, 1))
base_treinamento_normalizada = normalizador.fit_transform(base_treinamento)

# %%
base_treinamento_normalizada
# Out:
# array([[0.76501938, 0.77266112, 0.79682707, 0.76080559, 0.6838135 ,
#         0.04318274],
#        [0.7562984 , 0.78187106, 0.79733884, 0.79567784, 0.71590949,
#         0.0437121 ],
#        [0.78149225, 0.79253519, 0.82139202, 0.79715132, 0.71726583,
#         0.05170752],
#        ...,
#        [0.57122093, 0.57537562, 0.60696008, 0.58202356, 0.58202349,
#         0.03369652],
#        [0.57655039, 0.57489089, 0.60798362, 0.5844794 , 0.58447937,
#         0.02720006],
#        [0.57655039, 0.57343674, 0.61310133, 0.5844794 , 0.58447937,
#         0.        ]])

# %%
X = []
y = []
for i in range(90, 1242):
    X.append(base_treinamento_normalizada[i-90:i, 0:6]) #agora pegaremos 6 atributos
    y.append(base_treinamento_normalizada[i, 0])
X, y = np.array(X), np.array(y)

# %%
X[0]
# Out:
# array([[0.76501938, 0.77266112, 0.79682707, 0.76080559, 0.6838135 ,
#        [0.66182175, 0.66117305, 0.6765609 , 0.64685666, 0.57893629,
#         0.03144357],
#        [0.64341085, 0.6776539 , 0.68372569, 0.68516703, 0.61419665,
#         0.04400526],
#        [0.67877902, 0.69704314, 0.71903787, 0.69842833, 0.6264022 ,
#         0.04546845],
#        [0.69137592, 0.69122642, 0.7036848 , 0.67730848, 0.60696374,
#         0.03177292],
#        [0.66569772, 0.66941348, 0.6862846 , 0.67583495, 0.6056075 ,
#         0.03919891],
#        [0.65406982, 0.6572952 , 0.665302  , 0.63998039, 0.57260735,
#         0.05120333],
#        [0.64292631, 0.65341735, 0.68116684, 0.66306491, 0.59385423,
#         0.03397579],
#        [0.64147292, 0.64614639, 0.65813715, 0.63703343, 0.56989516,
#         0.05635362],
#        [0.63565891, 0.66262729, 0.665302  , 0.66895878, 0.5992789 ,
#         0.04077971],
#        [0.67587209, 0.68880271, 0.70777897, 0.6969548 , 0.625046  ,
#         0.0548714 ],
#        [0.68653106, 0.70382942, 0.71903787, 0.71660126, 0.64312846,
#         0.03461346],
#        [0.70300383, 0.73921474, 0.74411464, 0.73280952, 0.6580463 ,
#         0.04969664],
#        [0.71996119, 0.74600097, 0.76202661, 0.74852661, 0.67251211,
#         0.04766145],
#        [0.73982553, 0.74745521, 0.76867958, 0.73526526, 0.66030651,
#         0.05031056],
#        [0.76550388, 0.79059622, 0.80962134, 0.79666016, 0.71681365,
#         0.10120858],
#        [0.74854651, 0.76732913, 0.7840328 , 0.7804519 , 0.71911682,
#         0.06567045],
#        [0.75823643, 0.79301983, 0.80501535, 0.78831045, 0.72648688,
#         0.04828195],
#        [0.78924419, 0.79447407, 0.80706238, 0.77455795, 0.71358928,
#         0.06152981],
#        [0.76598837, 0.78041692, 0.80348004, 0.79223972, 0.73017189,
#         0.04455508],
#        [0.78488372, 0.79835191, 0.82702155, 0.80648339, 0.74353023,
#         0.03775975],
#        [0.80184109, 0.80222976, 0.82395082, 0.79027514, 0.72832946,
#         0.03492235],
#        [0.77761628, 0.78768783, 0.81729785, 0.7907662 , 0.72879006,
#         0.03271233],
#        [0.77325581, 0.78138628, 0.79785051, 0.77406679, 0.71312854,
#         0.0315204 ],
#        [0.7562984 , 0.75521086, 0.78096208, 0.75098236, 0.69147899,
#         0.03087142],
#        [0.74273261, 0.74697043, 0.77430911, 0.75392926, 0.69424286,
#         0.04384244],
#        [0.74127907, 0.74503146, 0.77840328, 0.75491163, 0.6951641 ,
#         0.03128876],
#        [0.74224806, 0.76635967, 0.78505624, 0.76375249, 0.7034554 ,
#         0.03586405]])

# %%
y[0]
# Out:
# 0.7611434108527131

# %%
X[1]
# Out:
# array([[0.7562984 , 0.78187106, 0.79733884, 0.79567784, 0.71590949,
#         0.0437121 ],
#        [0.78149225, 0.79253519, 0.82139202, 0.79715132, 0.71726583,
#         0.05170752],
#        [0.78875969, 0.7949588 , 0.81013311, 0.77996075, 0.70144373,
#         0.04015963],
#        [0.77083338, 0.77363063, 0.78505624, 0.75147351, 0.67522435,
#        [0.66569772, 0.66941348, 0.6862846 , 0.67583495, 0.6056075 ,
#         0.03919891],
#        [0.65406982, 0.6572952 , 0.665302  , 0.63998039, 0.57260735,
#         0.05120333],
#        [0.64292631, 0.65341735, 0.68116684, 0.66306491, 0.59385423,
#         0.03397579],
#        [0.64147292, 0.64614639, 0.65813715, 0.63703343, 0.56989516,
#         0.05635362],
#        [0.63565891, 0.66262729, 0.665302  , 0.66895878, 0.5992789 ,
#         0.04077971],
#        [0.67587209, 0.68880271, 0.70777897, 0.6969548 , 0.625046  ,
#         0.0548714 ],
#        [0.68653106, 0.70382942, 0.71903787, 0.71660126, 0.64312846,
#         0.03461346],
#        [0.70300383, 0.73921474, 0.74411464, 0.73280952, 0.6580463 ,
#         0.04969664],
#        [0.71996119, 0.74600097, 0.76202661, 0.74852661, 0.67251211,
#         0.04766145],
#        [0.73982553, 0.74745521, 0.76867958, 0.73526526, 0.66030651,
#         0.05031056],
#        [0.76550388, 0.79059622, 0.80962134, 0.79666016, 0.71681365,
#         0.10120858],
#        [0.74854651, 0.76732913, 0.7840328 , 0.7804519 , 0.71911682,
#         0.06567045],
#        [0.75823643, 0.79301983, 0.80501535, 0.78831045, 0.72648688,
#         0.04828195],
#        [0.78924419, 0.79447407, 0.80706238, 0.77455795, 0.71358928,
#         0.06152981],
#        [0.76598837, 0.78041692, 0.80348004, 0.79223972, 0.73017189,
#         0.04455508],
#        [0.78488372, 0.79835191, 0.82702155, 0.80648339, 0.74353023,
#         0.03775975],
#        [0.80184109, 0.80222976, 0.82395082, 0.79027514, 0.72832946,
#         0.03492235],
#        [0.77761628, 0.78768783, 0.81729785, 0.7907662 , 0.72879006,
#         0.03271233],
#        [0.77325581, 0.78138628, 0.79785051, 0.77406679, 0.71312854,
#         0.0315204 ],
#        [0.7562984 , 0.75521086, 0.78096208, 0.75098236, 0.69147899,
#         0.03087142],
#        [0.74273261, 0.74697043, 0.77430911, 0.75392926, 0.69424286,
#         0.04384244],
#        [0.74127907, 0.74503146, 0.77840328, 0.75491163, 0.6951641 ,
#         0.03128876],
#        [0.74224806, 0.76635967, 0.78505624, 0.76375249, 0.7034554 ,
#         0.03586405],
#        [0.76114341, 0.76490543, 0.80194478, 0.77062867, 0.70990428,
#         0.02724098]])

# %%
y[1]
# Out:
# 0.7611434108527131

# %%
X = torch.tensor(X, dtype = torch.float32)
y = torch.tensor(y, dtype = torch.float32)

# %%
dataset = torch.utils.data.TensorDataset(X, y)
loader = torch.utils.data.DataLoader(dataset, batch_size = 32, shuffle = True)

# %% [markdown]
# ## Etapa 3: Construção da rede neural recorrente

# %%
class regressor_LSTM(nn.Module):
    def __init__(self):
        super().__init__()

        # O primeiro input_size é o número de dimensões que cada dado tem em
        # cada timestep. Nesse caso, são 6 dimensões, uma para cada variável.
        self.lstm1 = nn.LSTM(input_size = 6, hidden_size = 100)
        self.lstm2 = nn.LSTM(100, 50)
        self.lstm3 = nn.LSTM(50, 50, dropout = 0.3, num_layers = 2)
        self.dropout = nn.Dropout(p = 0.3)
        self.linear = nn.Linear(in_features = 50, out_features = 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, X):

        X = X.permute(1, 0, 2)
        X, _ = self.lstm1(X)
        X = self.dropout(X)
        X, _ = self.lstm2(X)
        X = self.dropout(X)
        X, _ = self.lstm3(X)

        X = X[-1]
        X = self.dropout(X)
        X = self.linear(X)
        X = self.sigmoid(X)

        return X

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device
# Out:
# device(type='cuda')

# %%
regressor = regressor_LSTM()
criterion = nn.MSELoss()
optimizer = optim.Adam(regressor.parameters())

# %%
regressor.to(device)
# Out:
# regressor_LSTM(
#   (lstm1): LSTM(6, 100)
#   (lstm2): LSTM(100, 50)
#   (lstm3): LSTM(50, 50, num_layers=2, dropout=0.3)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (linear): Linear(in_features=50, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %% [markdown]
# ## Etapa 4: Treinamento do modelo

# %%
# Variáveis para o callback
ES_MIN_DELTA = 1e-10
ES_PATIENCE = 10
RLR_FACTOR = 0.2
RLR_PATIENCE = 5

# Inicializando o custo inicial para usar nos callbacks
min_loss = np.inf

# %%
for epoch in range(200):
    running_loss = 0.
    running_mae = 0.

    for i, data in enumerate(loader):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = regressor(inputs)
        outputs = outputs.flatten()

        loss = criterion(outputs, labels)
        loss.backward()

        optimizer.step()

        running_loss += loss.item()
        mae = mean_absolute_error(labels.detach().cpu().numpy().flatten(),
                                  outputs.detach().cpu().numpy().flatten())
        running_mae += mae

        # Imprimindo os dados referentes a esse loop
        print('\rÉpoca {:3d} - Loop {:3d} de {:3d}: custo {:03.5f} - MAE {:03.5f}'.format(epoch+1, i+1, len(loader), loss, mae), end = '\r')

    # Imprimindo os dados referentes a essa época
    running_loss /= len(loader)
    running_mae /= len(loader)
    print('ÉPOCA {:3d} finalizada: custo {:03.6f} - MAE {:03.6f}     '.format(epoch+1, running_loss, running_mae))

    # CALLBACKS

    # Salvar o modelo

    if running_loss < min_loss:
        print('**Custo reduzido de {:03.6f} para {:03.6f} ... salvando checkpoint'.format(min_loss, running_loss))
        torch.save(regressor.state_dict(), 'checkpoint.pth')
        min_loss = running_loss
        es_patience = 0
        rlr_patience = 0
    else:
        print('**Custo não reduziu, não salvando checkpoint')

        # Os demais parâmetros só serão considerados se o custo não tiver

        # Parada antecipada
        if running_loss - min_loss >= ES_MIN_DELTA:
            es_patience += 1
            if es_patience == ES_PATIENCE:
                print('--Critério de parada antecipada alcançado, parando o treinamento.')
                break

        # Reduzir a taxa de aprendizagem
        rlr_patience += 1
        if rlr_patience == RLR_PATIENCE:
            print('--Critério de redução de taxa de aprendizagem alcançado, reduzindo LR.')
            for param_group in optimizer.param_groups:
                param_group['lr'] *= RLR_FACTOR
            rlr_patience = 0
# Out:
# ÉPOCA   1 finalizada: custo 0.024632 - MAE 0.121068
# **Custo reduzido de inf para 0.024632 ... salvando checkpoint
# ÉPOCA   2 finalizada: custo 0.005172 - MAE 0.054308
# **Custo reduzido de 0.024632 para 0.005172 ... salvando checkpoint
# ÉPOCA   3 finalizada: custo 0.003266 - MAE 0.043635
# **Custo reduzido de 0.005172 para 0.003266 ... salvando checkpoint
# ÉPOCA   4 finalizada: custo 0.002855 - MAE 0.041098
# **Custo reduzido de 0.003266 para 0.002855 ... salvando checkpoint
# ÉPOCA   5 finalizada: custo 0.002677 - MAE 0.038900
# **Custo reduzido de 0.002855 para 0.002677 ... salvando checkpoint
# ÉPOCA   6 finalizada: custo 0.002578 - MAE 0.038799
# **Custo reduzido de 0.002677 para 0.002578 ... salvando checkpoint
# ÉPOCA   7 finalizada: custo 0.002238 - MAE 0.036347
# **Custo reduzido de 0.002578 para 0.002238 ... salvando checkpoint
# ÉPOCA   8 finalizada: custo 0.002108 - MAE 0.034395
# **Custo reduzido de 0.002238 para 0.002108 ... salvando checkpoint
# ÉPOCA   9 finalizada: custo 0.002044 - MAE 0.033935
# **Custo reduzido de 0.002108 para 0.002044 ... salvando checkpoint
# ÉPOCA  10 finalizada: custo 0.002148 - MAE 0.035385
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  11 finalizada: custo 0.001824 - MAE 0.032478
# **Custo reduzido de 0.002044 para 0.001824 ... salvando checkpoint
# ÉPOCA  12 finalizada: custo 0.001790 - MAE 0.031938
# **Custo reduzido de 0.001824 para 0.001790 ... salvando checkpoint
# ÉPOCA  13 finalizada: custo 0.001860 - MAE 0.032648
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  14 finalizada: custo 0.001809 - MAE 0.032420
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  15 finalizada: custo 0.001738 - MAE 0.030979
# **Custo reduzido de 0.001790 para 0.001738 ... salvando checkpoint
# ÉPOCA  16 finalizada: custo 0.001776 - MAE 0.032002
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  17 finalizada: custo 0.001550 - MAE 0.029422
# **Custo reduzido de 0.001738 para 0.001550 ... salvando checkpoint
# ÉPOCA  18 finalizada: custo 0.001585 - MAE 0.029771
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  19 finalizada: custo 0.001507 - MAE 0.028986
# **Custo reduzido de 0.001550 para 0.001507 ... salvando checkpoint
# ÉPOCA  20 finalizada: custo 0.001370 - MAE 0.027595
# **Custo reduzido de 0.001507 para 0.001370 ... salvando checkpoint
# ÉPOCA  21 finalizada: custo 0.001501 - MAE 0.028743
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  22 finalizada: custo 0.001397 - MAE 0.028499
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  23 finalizada: custo 0.001455 - MAE 0.028646
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  24 finalizada: custo 0.001313 - MAE 0.026808
# **Custo reduzido de 0.001370 para 0.001313 ... salvando checkpoint
# ÉPOCA  25 finalizada: custo 0.001211 - MAE 0.026002
# **Custo reduzido de 0.001313 para 0.001211 ... salvando checkpoint
# ÉPOCA  26 finalizada: custo 0.001254 - MAE 0.026601
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  27 finalizada: custo 0.001176 - MAE 0.025704
# **Custo reduzido de 0.001211 para 0.001176 ... salvando checkpoint
# ÉPOCA  28 finalizada: custo 0.001376 - MAE 0.027435
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  29 finalizada: custo 0.001294 - MAE 0.026913
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  30 finalizada: custo 0.001249 - MAE 0.026883
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  31 finalizada: custo 0.001156 - MAE 0.025339
# **Custo reduzido de 0.001176 para 0.001156 ... salvando checkpoint
# ÉPOCA  32 finalizada: custo 0.001238 - MAE 0.026006
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  33 finalizada: custo 0.001133 - MAE 0.025043
# **Custo reduzido de 0.001156 para 0.001133 ... salvando checkpoint
# ÉPOCA  34 finalizada: custo 0.001207 - MAE 0.026225
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  35 finalizada: custo 0.001128 - MAE 0.024886
# **Custo reduzido de 0.001133 para 0.001128 ... salvando checkpoint
# ÉPOCA  36 finalizada: custo 0.001004 - MAE 0.023791
# **Custo reduzido de 0.001128 para 0.001004 ... salvando checkpoint
# ÉPOCA  37 finalizada: custo 0.001187 - MAE 0.025012
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  38 finalizada: custo 0.001093 - MAE 0.024586
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  39 finalizada: custo 0.000996 - MAE 0.023722
# **Custo reduzido de 0.001004 para 0.000996 ... salvando checkpoint
# ÉPOCA  40 finalizada: custo 0.000998 - MAE 0.023545
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  41 finalizada: custo 0.000913 - MAE 0.022673
# **Custo reduzido de 0.000996 para 0.000913 ... salvando checkpoint
# ÉPOCA  42 finalizada: custo 0.001093 - MAE 0.024640
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  43 finalizada: custo 0.001026 - MAE 0.023628
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  44 finalizada: custo 0.001047 - MAE 0.024338
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  45 finalizada: custo 0.000968 - MAE 0.022972
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  46 finalizada: custo 0.000883 - MAE 0.022441
# **Custo reduzido de 0.000913 para 0.000883 ... salvando checkpoint
# ÉPOCA  47 finalizada: custo 0.001011 - MAE 0.023483
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  48 finalizada: custo 0.000985 - MAE 0.023213
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  49 finalizada: custo 0.000954 - MAE 0.023050
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  50 finalizada: custo 0.000919 - MAE 0.022366
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  51 finalizada: custo 0.000894 - MAE 0.022170
# **Custo não reduziu, não salvando checkpoint
# --Critério de redução de taxa de aprendizagem alcançado, reduzindo LR.
# ÉPOCA  52 finalizada: custo 0.000781 - MAE 0.021106
# **Custo reduzido de 0.000883 para 0.000781 ... salvando checkpoint
# ÉPOCA  53 finalizada: custo 0.000782 - MAE 0.020616
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  54 finalizada: custo 0.000772 - MAE 0.020217
# **Custo reduzido de 0.000781 para 0.000772 ... salvando checkpoint
# ÉPOCA  55 finalizada: custo 0.000768 - MAE 0.020127
# **Custo reduzido de 0.000772 para 0.000768 ... salvando checkpoint
# ÉPOCA  56 finalizada: custo 0.000786 - MAE 0.020569
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  57 finalizada: custo 0.000730 - MAE 0.019912
# **Custo reduzido de 0.000768 para 0.000730 ... salvando checkpoint
# ÉPOCA  58 finalizada: custo 0.000767 - MAE 0.020255
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  59 finalizada: custo 0.000796 - MAE 0.020397
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  60 finalizada: custo 0.000743 - MAE 0.020523
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  61 finalizada: custo 0.000721 - MAE 0.019865
# **Custo reduzido de 0.000730 para 0.000721 ... salvando checkpoint
# ÉPOCA  62 finalizada: custo 0.000731 - MAE 0.019694
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  63 finalizada: custo 0.000747 - MAE 0.020306
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  64 finalizada: custo 0.000757 - MAE 0.020324
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  65 finalizada: custo 0.000815 - MAE 0.020852
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  66 finalizada: custo 0.000732 - MAE 0.019814
# **Custo não reduziu, não salvando checkpoint
# --Critério de redução de taxa de aprendizagem alcançado, reduzindo LR.
# ÉPOCA  67 finalizada: custo 0.000730 - MAE 0.019655
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  68 finalizada: custo 0.000733 - MAE 0.019894
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  69 finalizada: custo 0.000729 - MAE 0.019570
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  70 finalizada: custo 0.000720 - MAE 0.019676
# **Custo reduzido de 0.000721 para 0.000720 ... salvando checkpoint
# ÉPOCA  71 finalizada: custo 0.000737 - MAE 0.020072
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  72 finalizada: custo 0.000694 - MAE 0.019092
# **Custo reduzido de 0.000720 para 0.000694 ... salvando checkpoint
# ÉPOCA  73 finalizada: custo 0.000724 - MAE 0.019598
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  74 finalizada: custo 0.000749 - MAE 0.019900
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  75 finalizada: custo 0.000722 - MAE 0.019129
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  76 finalizada: custo 0.000725 - MAE 0.019296
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  77 finalizada: custo 0.000696 - MAE 0.019466
# **Custo não reduziu, não salvando checkpoint
# --Critério de redução de taxa de aprendizagem alcançado, reduzindo LR.
# ÉPOCA  78 finalizada: custo 0.000705 - MAE 0.019193
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  79 finalizada: custo 0.000707 - MAE 0.019600
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  80 finalizada: custo 0.000681 - MAE 0.019130
# **Custo reduzido de 0.000694 para 0.000681 ... salvando checkpoint
# ÉPOCA  81 finalizada: custo 0.000745 - MAE 0.019580
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  82 finalizada: custo 0.000695 - MAE 0.019685
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  83 finalizada: custo 0.000695 - MAE 0.019266
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  84 finalizada: custo 0.000749 - MAE 0.020149
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  85 finalizada: custo 0.000719 - MAE 0.019720
# **Custo não reduziu, não salvando checkpoint
# --Critério de redução de taxa de aprendizagem alcançado, reduzindo LR.
# ÉPOCA  86 finalizada: custo 0.000714 - MAE 0.019837
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  87 finalizada: custo 0.000725 - MAE 0.019339
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  88 finalizada: custo 0.000708 - MAE 0.019526
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  89 finalizada: custo 0.000668 - MAE 0.019307
# **Custo reduzido de 0.000681 para 0.000668 ... salvando checkpoint
# ÉPOCA  90 finalizada: custo 0.000729 - MAE 0.019914
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  91 finalizada: custo 0.000715 - MAE 0.019464
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  92 finalizada: custo 0.000685 - MAE 0.019168
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  93 finalizada: custo 0.000709 - MAE 0.019241
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  94 finalizada: custo 0.000709 - MAE 0.019400
# **Custo não reduziu, não salvando checkpoint
# --Critério de redução de taxa de aprendizagem alcançado, reduzindo LR.
# ÉPOCA  95 finalizada: custo 0.000709 - MAE 0.019154
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  96 finalizada: custo 0.000670 - MAE 0.019058
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  97 finalizada: custo 0.000702 - MAE 0.019626
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  98 finalizada: custo 0.000721 - MAE 0.019649
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA  99 finalizada: custo 0.000657 - MAE 0.018372
# **Custo reduzido de 0.000668 para 0.000657 ... salvando checkpoint
# ÉPOCA 100 finalizada: custo 0.000696 - MAE 0.019342
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA 101 finalizada: custo 0.000661 - MAE 0.019105
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA 102 finalizada: custo 0.000735 - MAE 0.019425
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA 103 finalizada: custo 0.000673 - MAE 0.019147
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA 104 finalizada: custo 0.000709 - MAE 0.019282
# **Custo não reduziu, não salvando checkpoint
# --Critério de redução de taxa de aprendizagem alcançado, reduzindo LR.
# ÉPOCA 105 finalizada: custo 0.000761 - MAE 0.020022
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA 106 finalizada: custo 0.000703 - MAE 0.019497
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA 107 finalizada: custo 0.000692 - MAE 0.018845
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA 108 finalizada: custo 0.000722 - MAE 0.019578
# **Custo não reduziu, não salvando checkpoint
# ÉPOCA 109 finalizada: custo 0.000685 - MAE 0.018797
# **Custo não reduziu, não salvando checkpoint
# --Critério de parada antecipada alcançado, parando o treinamento.

# %% [markdown]
# ## Etapa 5: Processamento da base de teste

# %%
base_teste = pd.read_csv('petr4_teste.csv')
preco_real_teste = base_teste.iloc[:, 1:2].values
base_completa = pd.concat([base, base_teste])

# %%
base_completa.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2013-01-02  19.990000  20.209999  19.690001  19.690001  18.086271
# 1  2013-01-03  19.809999  20.400000  19.700001  20.400000  18.738441
# 2  2013-01-04  20.330000  20.620001  20.170000  20.430000  18.766001
# 3  2013-01-07  20.480000  20.670000  19.950001  20.080000  18.444506
# 4  2013-01-08  20.110001  20.230000  19.459999  19.500000  17.911745
#
#        Volume
# 0  30182600.0
# 1  30552600.0
# 2  36141000.0
# 3  28069600.0
# 4  29091300.0

# %%
base_completa = base_completa.drop('Date', axis = 1)

# %%
entradas = base_completa[len(base_completa) - len(base_teste) - 90:].values
entradas = normalizador.transform(entradas)

# %%
X_teste = []
for i in range(90, 112):
    X_teste.append(entradas[i-90:i, 0:6])
X_teste = np.array(X_teste)

# %%
X_teste = torch.tensor(X_teste, device = device, dtype = torch.float32)

# %% [markdown]
# ## Etapa 6: Previsões

# %%
regressor.eval()
previsoes = regressor(X_teste)
previsoes = previsoes.detach().cpu().numpy().reshape(-1, 1)

# %%
previsoes
# Out:
# array([[0.5811573 ],
#        [0.59100693],
#        [0.6045641 ],
#        [0.6149932 ],
#        [0.6163652 ],
#        [0.6193363 ],
#        [0.62511015],
#        [0.62107694],
#        [0.62636983],
#        [0.63531864],
#        [0.64153117],
#        [0.6504667 ],
#        [0.6768153 ],
#        [0.6894299 ],
#        [0.6876909 ],
#        [0.68785274],
#        [0.68520105],
#        [0.7136883 ],
#        [0.73949003],
#        [0.752924  ],
#        [0.7591012 ],
#        [0.7511063 ]], dtype=float32)

# %%
normalizador_previsao = MinMaxScaler(feature_range = (0, 1))
normalizador_previsao.fit(base_treinamento[:, 0:1])
# Out:
# MinMaxScaler()

# %%
previsoes = normalizador_previsao.inverse_transform(previsoes)

# %%
previsoes
# Out:
# array([[16.195087],
#        [16.398382],
#        [16.678202],
#        [16.89346 ],
#        [16.921778],
#        [16.9831  ],
#        [17.102274],
#        [17.019028],
#        [17.128273],
#        [17.312977],
#        [17.441202],
#        [17.625631],
#        [18.169466],
#        [18.429832],
#        [18.39394 ],
#        [18.39728 ],
#        [18.342548],
#        [18.930527],
#        [19.463074],
#        [19.74035 ],
#        [19.86785 ],
#        [19.702833]], dtype=float32)

# %%
previsoes.mean()
# Out:
# 17.869867

# %%
preco_real_teste.mean()
# Out:
# 17.87454563636364

# %%
plt.plot(preco_real_teste, color = 'red', label = 'Preço real')
plt.plot(previsoes, color = 'blue', label = 'Previsões')
plt.title('Previsão preço das ações')
plt.xlabel('Tempo')
plt.ylabel('Valor Yahoo')
plt.legend()
